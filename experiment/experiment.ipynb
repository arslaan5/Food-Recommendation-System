# %%
import pandas as pd

# %%
recipes_df = pd.read_csv('../data/archive/recipes.csv')
reviews_df = pd.read_csv('../data/archive/reviews.csv')

# %%
recipes_df.head()
# Out:
#    RecipeId                               Name  AuthorId      AuthorName  \
# 0        38  Low-Fat Berry Blue Frozen Dessert      1533          Dancer
# 1        39                            Biryani      1567        elly9812
# 2        40                      Best Lemonade      1566  Stephen Little
# 3        41     Carina's Tofu-Vegetable Kebabs      1586         Cyclopz
# 4        42                       Cabbage Soup      1538       Duckie067
#
#   CookTime PrepTime TotalTime         DatePublished  \
# 0    PT24H    PT45M  PT24H45M  1999-08-09T21:46:00Z
# 1    PT25M     PT4H   PT4H25M  1999-08-29T13:12:00Z
# 2     PT5M    PT30M     PT35M  1999-09-05T19:52:00Z
# 3    PT20M    PT24H  PT24H20M  1999-09-03T14:54:00Z
# 4    PT30M    PT20M     PT50M  1999-09-19T06:19:00Z
#
#                                          Description  \
# 0  Make and share this Low-Fat Berry Blue Frozen ...
# 1  Make and share this Biryani recipe from Food.com.
# ...

# %%
recipes_df.columns
# Out:
# Index(['RecipeId', 'Name', 'AuthorId', 'AuthorName', 'CookTime', 'PrepTime',
#        'TotalTime', 'DatePublished', 'Description', 'Images', 'RecipeCategory',
#        'Keywords', 'RecipeIngredientQuantities', 'RecipeIngredientParts',
#        'AggregatedRating', 'ReviewCount', 'Calories', 'FatContent',
#        'SaturatedFatContent', 'CholesterolContent', 'SodiumContent',
#        'CarbohydrateContent', 'FiberContent', 'SugarContent', 'ProteinContent',
#        'RecipeServings', 'RecipeYield', 'RecipeInstructions'],
#       dtype='object')

# %%
recipes_df.isnull().sum()
# Out:
# RecipeId                           0
# Name                               0
# AuthorId                           0
# AuthorName                         0
# CookTime                       82545
# PrepTime                           0
# TotalTime                          0
# DatePublished                      0
# Description                        5
# Images                             1
# RecipeCategory                   751
# Keywords                       17237
# RecipeIngredientQuantities         3
# RecipeIngredientParts              0
# AggregatedRating              253223
# ReviewCount                   247489
# Calories                           0
# FatContent                         0
# SaturatedFatContent                0
# CholesterolContent                 0
# SodiumContent                      0
# CarbohydrateContent                0
# FiberContent                       0
# SugarContent                       0
# ProteinContent                     0
# ...

# %%
recipes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 522517 entries, 0 to 522516
# Data columns (total 28 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   RecipeId                    522517 non-null  int64
#  1   Name                        522517 non-null  object
#  2   AuthorId                    522517 non-null  int64
#  3   AuthorName                  522517 non-null  object
#  4   CookTime                    439972 non-null  object
#  5   PrepTime                    522517 non-null  object
#  6   TotalTime                   522517 non-null  object
#  7   DatePublished               522517 non-null  object
#  8   Description                 522512 non-null  object
#  9   Images                      522516 non-null  object
#  10  RecipeCategory              521766 non-null  object
#  11  Keywords                    505280 non-null  object
#  12  RecipeIngredientQuantities  522514 non-null  object
# ...

# %%
recipes_df.iloc[4]['Images']
# Out:
# '"https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/42/picVEMxk8.jpg"'

# %%
reviews_df.head()
# Out:
#    ReviewId  RecipeId  AuthorId        AuthorName  Rating  \
# 0         2       992      2008         gayg msft       5
# 1         7      4384      1634     Bill Hilbrich       4
# 2         9      4523      2046  Gay Gilmore ckpt       2
# 3        13      7435      1773     Malarkey Test       5
# 4        14        44      2085        Tony Small       5
#
#                                               Review         DateSubmitted  \
# 0       better than any you can get at a restaurant!  2000-01-25T21:44:00Z
# 1  I cut back on the mayo, and made up the differ...  2001-10-17T16:49:59Z
# 2  i think i did something wrong because i could ...  2000-02-25T09:00:00Z
# 3  easily the best i have ever had.  juicy flavor...  2000-03-13T21:15:00Z
# 4                                 An excellent dish.  2000-03-28T12:51:00Z
#
#            DateModified
# 0  2000-01-25T21:44:00Z
# 1  2001-10-17T16:49:59Z
# 2  2000-02-25T09:00:00Z
# 3  2000-03-13T21:15:00Z
# 4  2000-03-28T12:51:00Z

# %%
reviews_df.columns
# Out:
# Index(['ReviewId', 'RecipeId', 'AuthorId', 'AuthorName', 'Rating', 'Review',
#        'DateSubmitted', 'DateModified'],
#       dtype='object')

# %%
recipes_df.iloc[1]
# Out:
# RecipeId                                                                     39
# Name                                                                    Biryani
# AuthorId                                                                   1567
# AuthorName                                                             elly9812
# CookTime                                                                  PT25M
# PrepTime                                                                   PT4H
# TotalTime                                                               PT4H25M
# DatePublished                                              1999-08-29T13:12:00Z
# Description                   Make and share this Biryani recipe from Food.com.
# Images                        c("https://img.sndimg.com/food/image/upload/w_...
# RecipeCategory                                                   Chicken Breast
# Keywords                      c("Chicken Thigh & Leg", "Chicken", "Poultry",...
# ...

# %%
reduced_df = recipes_df[['RecipeId', 'Name', 'Images', 'RecipeCategory', 'Keywords', 'RecipeIngredientParts', 'RecipeInstructions', 'Calories', 'FatContent', 'CholesterolContent', 'CarbohydrateContent', 'FiberContent', 'ProteinContent', 'Description',]]

# %%
reduced_df.head()
# Out:
#    RecipeId                               Name  \
# 0        38  Low-Fat Berry Blue Frozen Dessert
# 1        39                            Biryani
# 2        40                      Best Lemonade
# 3        41     Carina's Tofu-Vegetable Kebabs
# 4        42                       Cabbage Soup
#
#                                               Images   RecipeCategory  \
# 0  c("https://img.sndimg.com/food/image/upload/w_...  Frozen Desserts
# 1  c("https://img.sndimg.com/food/image/upload/w_...   Chicken Breast
# 2  c("https://img.sndimg.com/food/image/upload/w_...        Beverages
# 3  c("https://img.sndimg.com/food/image/upload/w_...         Soy/Tofu
# 4  "https://img.sndimg.com/food/image/upload/w_55...        Vegetable
#
#                                             Keywords  \
# 0  c("Dessert", "Low Protein", "Low Cholesterol",...
# 1  c("Chicken Thigh & Leg", "Chicken", "Poultry",...
# 2  c("Low Protein", "Low Cholesterol", "Healthy",...
# ...

# %%
reduced_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 522517 entries, 0 to 522516
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   RecipeId               522517 non-null  int64
#  1   Name                   522517 non-null  object
#  2   Images                 522516 non-null  object
#  3   RecipeCategory         521766 non-null  object
#  4   Keywords               505280 non-null  object
#  5   RecipeIngredientParts  522517 non-null  object
#  6   RecipeInstructions     522517 non-null  object
#  7   Calories               522517 non-null  float64
#  8   FatContent             522517 non-null  float64
#  9   CholesterolContent     522517 non-null  float64
#  10  CarbohydrateContent    522517 non-null  float64
#  11  FiberContent           522517 non-null  float64
#  12  ProteinContent         522517 non-null  float64
#  13  Description            522512 non-null  object
# ...

# %%
reduced_df.isnull().sum()
# Out:
# RecipeId                     0
# Name                         0
# Images                       1
# RecipeCategory             751
# Keywords                 17237
# RecipeIngredientParts        0
# RecipeInstructions           0
# Calories                     0
# FatContent                   0
# CholesterolContent           0
# CarbohydrateContent          0
# FiberContent                 0
# ProteinContent               0
# Description                  5
# dtype: int64

# %%
reduced_df.shape
# Out:
# (522517, 14)

# %%
reduced_df.dropna(inplace=True)
# Out:
# C:\Users\arsla\AppData\Local\Temp\ipykernel_11356\1068235543.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_df.dropna(inplace=True)

# %%
reduced_df.shape
# Out:
# (505275, 14)

# %%
reduced_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
reduced_df.iloc[0].Images
# Out:
# 'c("https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/38/YUeirxMLQaeE1h3v3qnM_229%20berry%20blue%20frzn%20dess.jpg", "https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/38/AFPDDHATWzQ0b1CDpDAT_255%20berry%20blue%20frzn%20dess.jpg", "https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/38/UYgf9nwMT2SGGJCuzILO_228%20berry%20blue%20frzn%20dess.jpg", "https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/38/PeBMJN2TGSaYks2759BA_20140722_202142.jpg", \n"https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/38/picuaETeN.jpg", "https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/38/pictzvxW5.jpg")'

# %%
reduced_df.head()
# Out:
#    RecipeId                               Name  \
# 0        38  Low-Fat Berry Blue Frozen Dessert
# 1        39                            Biryani
# 2        40                      Best Lemonade
# 3        41     Carina's Tofu-Vegetable Kebabs
# 4        42                       Cabbage Soup
#
#                                               Images   RecipeCategory  \
# 0  c("https://img.sndimg.com/food/image/upload/w_...  Frozen Desserts
# 1  c("https://img.sndimg.com/food/image/upload/w_...   Chicken Breast
# 2  c("https://img.sndimg.com/food/image/upload/w_...        Beverages
# 3  c("https://img.sndimg.com/food/image/upload/w_...         Soy/Tofu
# 4  "https://img.sndimg.com/food/image/upload/w_55...        Vegetable
#
#                                             Keywords  \
# 0  c("Dessert", "Low Protein", "Low Cholesterol",...
# 1  c("Chicken Thigh & Leg", "Chicken", "Poultry",...
# 2  c("Low Protein", "Low Cholesterol", "Healthy",...
# ...

# %%
reduced_df
# Out:
#         RecipeId                                              Name  \
# 0             38                 Low-Fat Berry Blue Frozen Dessert
# 1             39                                           Biryani
# 2             40                                     Best Lemonade
# 3             41                    Carina's Tofu-Vegetable Kebabs
# 4             42                                      Cabbage Soup
# ...          ...                                               ...
# 522512    541379                    Meg's Fresh Ginger Gingerbread
# 522513    541380  Roast Prime Rib au Poivre with Mixed Peppercorns
# 522514    541381                             Kirshwasser Ice Cream
# 522515    541382          Quick & Easy Asian Cucumber Salmon Rolls
# 522516    541383                           Spicy Baked Scotch Eggs
#
#                                                    Images   RecipeCategory  \
# 0       c("https://img.sndimg.com/food/image/upload/w_...  Frozen Desserts
# ...

# %%
reduced_df['Images']
# Out:
# 0         c("https://img.sndimg.com/food/image/upload/w_...
# 1         c("https://img.sndimg.com/food/image/upload/w_...
# 2         c("https://img.sndimg.com/food/image/upload/w_...
# 3         c("https://img.sndimg.com/food/image/upload/w_...
# 4         "https://img.sndimg.com/food/image/upload/w_55...
#                                 ...
# 522512                                         character(0)
# 522513    "https://img.sndimg.com/food/image/upload/w_55...
# 522514                                         character(0)
# 522515    "https://img.sndimg.com/food/image/upload/w_55...
# 522516                                         character(0)
# Name: Images, Length: 505275, dtype: object

# %%
import numpy as np

# %%
reduced_df['Images'].replace("character(0)", np.nan, inplace=True)
# Out:
# C:\Users\arsla\AppData\Local\Temp\ipykernel_11356\2482350999.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_df['Images'].replace("character(0)", np.nan, inplace=True)

# %%
reduced_df
# Out:
#         RecipeId                                              Name  \
# 0             38                 Low-Fat Berry Blue Frozen Dessert
# 1             39                                           Biryani
# 2             40                                     Best Lemonade
# 3             41                    Carina's Tofu-Vegetable Kebabs
# 4             42                                      Cabbage Soup
# ...          ...                                               ...
# 522512    541379                    Meg's Fresh Ginger Gingerbread
# 522513    541380  Roast Prime Rib au Poivre with Mixed Peppercorns
# 522514    541381                             Kirshwasser Ice Cream
# 522515    541382          Quick & Easy Asian Cucumber Salmon Rolls
# 522516    541383                           Spicy Baked Scotch Eggs
#
#                                                    Images   RecipeCategory  \
# 0       c("https://img.sndimg.com/food/image/upload/w_...  Frozen Desserts
# ...

# %%
reduced_df.dropna(inplace=True)
# Out:
# C:\Users\arsla\AppData\Local\Temp\ipykernel_11356\1068235543.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_df.dropna(inplace=True)

# %%
reduced_df
# Out:
#         RecipeId                                              Name  \
# 0             38                 Low-Fat Berry Blue Frozen Dessert
# 1             39                                           Biryani
# 2             40                                     Best Lemonade
# 3             41                    Carina's Tofu-Vegetable Kebabs
# 4             42                                      Cabbage Soup
# ...          ...                                               ...
# 522503    541370                  Minty Whipped Shortbread Cookies
# 522509    541376                     Spanish Coffee with Tia Maria
# 522511    541378                         Meg's Pumpkin Spice Bread
# 522513    541380  Roast Prime Rib au Poivre with Mixed Peppercorns
# 522515    541382          Quick & Easy Asian Cucumber Salmon Rolls
#
#                                                    Images   RecipeCategory  \
# 0       c("https://img.sndimg.com/food/image/upload/w_...  Frozen Desserts
# ...

# %%
reduced_df['Images'][20]
# Out:
# 'c("https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/58/picnE8qoe.jpg", "https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/58/picwiayaY.jpg", "https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/58/picAaGXgc.jpg", "https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/58/picD2ey4Z.jpg", "https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/58/picKtSTwb.jpg", \n"https://img.sndimg.com/food/image/upload/w_555,h_416,c_fit,fl_progressive,q_95/v1/img/recipes/58/picY2Aqui.jpg")'

# %%
reduced_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 161513 entries, 0 to 522515
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   RecipeId               161513 non-null  int64
#  1   Name                   161513 non-null  object
#  2   Images                 161513 non-null  object
#  3   RecipeCategory         161513 non-null  object
#  4   Keywords               161513 non-null  object
#  5   RecipeIngredientParts  161513 non-null  object
#  6   RecipeInstructions     161513 non-null  object
#  7   Calories               161513 non-null  float64
#  8   FatContent             161513 non-null  float64
#  9   CholesterolContent     161513 non-null  float64
#  10  CarbohydrateContent    161513 non-null  float64
#  11  FiberContent           161513 non-null  float64
#  12  ProteinContent         161513 non-null  float64
#  13  Description            161513 non-null  object
# ...

# %%
import ast

def convert_to_list(keywords_str):
    if not isinstance(keywords_str, str):  # Handle NaN or non-string cases
        return []  
    try:
        formatted_str = keywords_str.replace("c(", "[").replace(")", "]")  # Convert to Python list format
        return ast.literal_eval(formatted_str)  # Convert string to actual list
    except (SyntaxError, ValueError):
        return []  # Return empty list if conversion fails

# %%
reduced_df['Keywords'] = reduced_df['Keywords'].apply(convert_to_list)
reduced_df['RecipeIngredientParts'] = reduced_df['RecipeIngredientParts'].apply(convert_to_list)
# Out:
# C:\Users\arsla\AppData\Local\Temp\ipykernel_11356\3169869164.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_df['Keywords'] = reduced_df['Keywords'].apply(convert_to_list)
# C:\Users\arsla\AppData\Local\Temp\ipykernel_11356\3169869164.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_df['RecipeIngredientParts'] = reduced_df['RecipeIngredientParts'].apply(convert_to_list)

# %%
reduced_df.drop('RecipeInstructions', axis=1, inplace=True)
# Out:
# C:\Users\arsla\AppData\Local\Temp\ipykernel_11356\2817705563.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_df.drop('RecipeInstructions', axis=1, inplace=True)

# %%
reduced_df.head()
# Out:
#    RecipeId                               Name  \
# 0        38  Low-Fat Berry Blue Frozen Dessert
# 1        39                            Biryani
# 2        40                      Best Lemonade
# 3        41     Carina's Tofu-Vegetable Kebabs
# 4        42                       Cabbage Soup
#
#                                               Images   RecipeCategory  \
# 0  c("https://img.sndimg.com/food/image/upload/w_...  Frozen Desserts
# 1  c("https://img.sndimg.com/food/image/upload/w_...   Chicken Breast
# 2  c("https://img.sndimg.com/food/image/upload/w_...        Beverages
# 3  c("https://img.sndimg.com/food/image/upload/w_...         Soy/Tofu
# 4  "https://img.sndimg.com/food/image/upload/w_55...        Vegetable
#
#                                             Keywords  \
# 0  [Dessert, Low Protein, Low Cholesterol, Health...
# 1  [Chicken Thigh & Leg, Chicken, Poultry, Meat, ...
# 2  [Low Protein, Low Cholesterol, Healthy, Summer...
# ...

# %%
recipes_df['Description'][10]
# Out:
# 'Make and share this Boston Cream Pie recipe from Food.com.'

# %%
reduced_df['Keywords'][:1].values
# Out:
# array([list(['Dessert', 'Low Protein', 'Low Cholesterol', 'Healthy', 'Free Of...', 'Summer', 'Weeknight', 'Freezer', 'Easy'])],
#       dtype=object)

# %%
print(reduced_df['Keywords'].apply(type).value_counts())
# Out:
# Keywords
# <class 'list'>    150233
# <class 'str'>      11280
# Name: count, dtype: int64

# %%
string_rows = reduced_df[reduced_df['Keywords'].apply(lambda x: isinstance(x, str))]
# print(string_rows.head(10))  # View first 10 rows
string_rows['Keywords'][:10]
# Out:
# 96     < 4 Hours
# 120         Oven
# 121         Oven
# 240         Oven
# 311    < 30 Mins
# 345    < 60 Mins
# 475         Oven
# 614         Oven
# 705    < 60 Mins
# 779    < 15 Mins
# Name: Keywords, dtype: object

# %%
reduced_df['Keywords'].apply(repr).head(20)  # Shows whitespace issues
# Out:
# 0     ['Dessert', 'Low Protein', 'Low Cholesterol', ...
# 1     ['Chicken Thigh & Leg', 'Chicken', 'Poultry', ...
# 2     ['Low Protein', 'Low Cholesterol', 'Healthy', ...
# 3     ['Beans', 'Vegetable', 'Low Cholesterol', 'Wee...
# 4     ['Low Protein', 'Vegan', 'Low Cholesterol', 'H...
# 6                      ['Poultry', 'Meat', '< 60 Mins']
# 7     ['Dessert', 'Healthy', 'Weeknight', 'Oven', '<...
# 9     ['Cookie & Brownie', 'Fruit', 'Nuts', 'Weeknig...
# 11    ['Chicken', 'Poultry', 'Meat', 'European', 'Ve...
# 12    ['Cookie & Brownie', 'European', 'Weeknight', ...
# 14    ['Low Cholesterol', 'High Protein', 'Healthy',...
# 16      ['Vegetable', 'Weeknight', 'Oven', '< 4 Hours']
# 17    ['Mexican', 'Low Protein', 'Low Cholesterol', ...
# 18             ['Dessert', 'Oven', '< 4 Hours', 'Easy']
# 20    ['Vegetable', 'Meat', 'Low Cholesterol', 'Heal...
# 21    ['European', 'Low Cholesterol', 'Healthy', 'Sp...
# 27    ['Low Protein', 'Low Cholesterol', 'Healthy', ...
# ...

# %%
reduced_df['Keywords'] = reduced_df['Keywords'].apply(lambda x: x.strip() if isinstance(x, str) else x)
# Out:
# C:\Users\arsla\AppData\Local\Temp\ipykernel_11356\3562488945.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_df['Keywords'] = reduced_df['Keywords'].apply(lambda x: x.strip() if isinstance(x, str) else x)

# %%
reduced_df['Keywords'].apply(repr).head(100)
# Out:
# 0      ['Dessert', 'Low Protein', 'Low Cholesterol', ...
# 1      ['Chicken Thigh & Leg', 'Chicken', 'Poultry', ...
# 2      ['Low Protein', 'Low Cholesterol', 'Healthy', ...
# 3      ['Beans', 'Vegetable', 'Low Cholesterol', 'Wee...
# 4      ['Low Protein', 'Vegan', 'Low Cholesterol', 'H...
#                              ...
# 316                 ['Potato', 'Vegetable', '< 60 Mins']
# 317      ['Low Protein', 'Low Cholesterol', '< 15 Mins']
# 319    ['Beverages', 'Low Protein', '< 15 Mins', 'Easy']
# 320                               ['Fruit', '< 30 Mins']
# 321                     ['Dessert', '< 15 Mins', 'Easy']
# Name: Keywords, Length: 100, dtype: object

# %%
reduced_df['Keywords'] = reduced_df['Keywords'].apply(lambda x: [x] if isinstance(x, str) else x)
# Out:
# C:\Users\arsla\AppData\Local\Temp\ipykernel_11356\894815908.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_df['Keywords'] = reduced_df['Keywords'].apply(lambda x: [x] if isinstance(x, str) else x)

# %%
reduced_df.head()
# Out:
#    RecipeId                               Name  \
# 0        38  Low-Fat Berry Blue Frozen Dessert
# 1        39                            Biryani
# 2        40                      Best Lemonade
# 3        41     Carina's Tofu-Vegetable Kebabs
# 4        42                       Cabbage Soup
#
#                                               Images   RecipeCategory  \
# 0  c("https://img.sndimg.com/food/image/upload/w_...  Frozen Desserts
# 1  c("https://img.sndimg.com/food/image/upload/w_...   Chicken Breast
# 2  c("https://img.sndimg.com/food/image/upload/w_...        Beverages
# 3  c("https://img.sndimg.com/food/image/upload/w_...         Soy/Tofu
# 4  "https://img.sndimg.com/food/image/upload/w_55...        Vegetable
#
#                                             Keywords  \
# 0  [Dessert, Low Protein, Low Cholesterol, Health...
# 1  [Chicken Thigh & Leg, Chicken, Poultry, Meat, ...
# 2  [Low Protein, Low Cholesterol, Healthy, Summer...
# ...

# %%
print(reduced_df['Keywords'].apply(type).value_counts())
# Out:
# Keywords
# <class 'list'>    161513
# Name: count, dtype: int64

# %%
print(reduced_df['RecipeIngredientParts'].apply(type).value_counts())
# Out:
# RecipeIngredientParts
# <class 'list'>    158685
# <class 'str'>       2828
# Name: count, dtype: int64

# %%
reduced_df['RecipeIngredientParts'] = reduced_df['RecipeIngredientParts'].apply(lambda x: [x] if isinstance(x, str) else x)
# Out:
# C:\Users\arsla\AppData\Local\Temp\ipykernel_11356\3084896635.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_df['RecipeIngredientParts'] = reduced_df['RecipeIngredientParts'].apply(lambda x: [x] if isinstance(x, str) else x)

# %%
print(reduced_df['RecipeIngredientParts'].apply(type).value_counts())
# Out:
# RecipeIngredientParts
# <class 'list'>    161513
# Name: count, dtype: int64

# %%
reduced_df['Images'] = reduced_df['Images'].apply(convert_to_list)
# Out:
# C:\Users\arsla\AppData\Local\Temp\ipykernel_11356\681085945.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_df['Images'] = reduced_df['Images'].apply(convert_to_list)

# %%
reduced_df.head()
# Out:
#    RecipeId                               Name  \
# 0        38  Low-Fat Berry Blue Frozen Dessert
# 1        39                            Biryani
# 2        40                      Best Lemonade
# 3        41     Carina's Tofu-Vegetable Kebabs
# 4        42                       Cabbage Soup
#
#                                               Images   RecipeCategory  \
# 0  [https://img.sndimg.com/food/image/upload/w_55...  Frozen Desserts
# 1  [https://img.sndimg.com/food/image/upload/w_55...   Chicken Breast
# 2  [https://img.sndimg.com/food/image/upload/w_55...        Beverages
# 3  [https://img.sndimg.com/food/image/upload/w_55...         Soy/Tofu
# 4  https://img.sndimg.com/food/image/upload/w_555...        Vegetable
#
#                                             Keywords  \
# 0  [Dessert, Low Protein, Low Cholesterol, Health...
# 1  [Chicken Thigh & Leg, Chicken, Poultry, Meat, ...
# 2  [Low Protein, Low Cholesterol, Healthy, Summer...
# ...

# %%
print(reduced_df['Images'].apply(type).value_counts())
# Out:
# Images
# <class 'list'>    81327
# <class 'str'>     80186
# Name: count, dtype: int64

# %%
reduced_df['Images'] = reduced_df['Images'].apply(lambda x: [x] if isinstance(x, str) else x)
# Out:
# C:\Users\arsla\AppData\Local\Temp\ipykernel_11356\2908911043.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_df['Images'] = reduced_df['Images'].apply(lambda x: [x] if isinstance(x, str) else x)

# %%
print(reduced_df['Images'].apply(type).value_counts())
# Out:
# Images
# <class 'list'>    161513
# Name: count, dtype: int64

# %%
reduced_df.head()
# Out:
#    RecipeId                               Name  \
# 0        38  Low-Fat Berry Blue Frozen Dessert
# 1        39                            Biryani
# 2        40                      Best Lemonade
# 3        41     Carina's Tofu-Vegetable Kebabs
# 4        42                       Cabbage Soup
#
#                                               Images   RecipeCategory  \
# 0  [https://img.sndimg.com/food/image/upload/w_55...  Frozen Desserts
# 1  [https://img.sndimg.com/food/image/upload/w_55...   Chicken Breast
# 2  [https://img.sndimg.com/food/image/upload/w_55...        Beverages
# 3  [https://img.sndimg.com/food/image/upload/w_55...         Soy/Tofu
# 4  [https://img.sndimg.com/food/image/upload/w_55...        Vegetable
#
#                                             Keywords  \
# 0  [Dessert, Low Protein, Low Cholesterol, Health...
# 1  [Chicken Thigh & Leg, Chicken, Poultry, Meat, ...
# 2  [Low Protein, Low Cholesterol, Healthy, Summer...
# ...

# %%
reduced_df.drop('Description', axis=1, inplace=True)
# Out:
# C:\Users\arsla\AppData\Local\Temp\ipykernel_11356\3190798323.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_df.drop('Description', axis=1, inplace=True)

# %%
reduced_df['Name'] = reduced_df['Name'].apply(lambda x: [x] if isinstance(x, str) else x)
reduced_df['RecipeCategory'] = reduced_df['RecipeCategory'].apply(lambda x: [x] if isinstance(x, str) else x)
# Out:
# C:\Users\arsla\AppData\Local\Temp\ipykernel_11356\2536559342.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_df['Name'] = reduced_df['Name'].apply(lambda x: [x] if isinstance(x, str) else x)
# C:\Users\arsla\AppData\Local\Temp\ipykernel_11356\2536559342.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_df['RecipeCategory'] = reduced_df['RecipeCategory'].apply(lambda x: [x] if isinstance(x, str) else x)

# %%
reduced_df.head()
# Out:
#    RecipeId                                 Name  \
# 0        38  [Low-Fat Berry Blue Frozen Dessert]
# 1        39                            [Biryani]
# 2        40                      [Best Lemonade]
# 3        41     [Carina's Tofu-Vegetable Kebabs]
# 4        42                       [Cabbage Soup]
#
#                                               Images     RecipeCategory  \
# 0  [https://img.sndimg.com/food/image/upload/w_55...  [Frozen Desserts]
# 1  [https://img.sndimg.com/food/image/upload/w_55...   [Chicken Breast]
# 2  [https://img.sndimg.com/food/image/upload/w_55...        [Beverages]
# 3  [https://img.sndimg.com/food/image/upload/w_55...         [Soy/Tofu]
# 4  [https://img.sndimg.com/food/image/upload/w_55...        [Vegetable]
#
#                                             Keywords  \
# 0  [Dessert, Low Protein, Low Cholesterol, Health...
# 1  [Chicken Thigh & Leg, Chicken, Poultry, Meat, ...
# 2  [Low Protein, Low Cholesterol, Healthy, Summer...
# ...

# %%
reduced_df['RecipeIngredientParts'][0]
# Out:
# ['blueberries', 'granulated sugar', 'vanilla yogurt', 'lemon juice']

# %%
def format_keywords(keywords):
    # Capitalize the first letter of each word and remove spaces
    formatted_words = [keyword.title() for keyword in keywords]
    return [word.replace(" ", "") for word in formatted_words]

# %%
reduced_df.tail()
# Out:
#         RecipeId                                               Name  \
# 522503    541370                 [Minty Whipped Shortbread Cookies]
# 522509    541376                    [Spanish Coffee with Tia Maria]
# 522511    541378                        [Meg's Pumpkin Spice Bread]
# 522513    541380  [Roast Prime Rib au Poivre with Mixed Pepperco...
# 522515    541382         [Quick & Easy Asian Cucumber Salmon Rolls]
#
#                                                    Images    RecipeCategory  \
# 522503  [https://img.sndimg.com/food/image/upload/w_55...    [Drop Cookies]
# 522509  [https://img.sndimg.com/food/image/upload/w_55...       [Beverages]
# 522511  [https://img.sndimg.com/food/image/upload/w_55...    [Quick Breads]
# 522513  [https://img.sndimg.com/food/image/upload/w_55...  [Very Low Carbs]
# 522515  [https://img.sndimg.com/food/image/upload/w_55...        [Canadian]
#
#                                                  Keywords  \
# ...

# %%
reduced_df['Name'] = reduced_df['Name'].apply(format_keywords)
reduced_df['RecipeCategory'] = reduced_df['RecipeCategory'].apply(format_keywords)
reduced_df['Keywords'] = reduced_df['Keywords'].apply(format_keywords)
reduced_df['RecipeIngredientParts'] = reduced_df['RecipeIngredientParts'].apply(format_keywords)
# Out:
# C:\Users\arsla\AppData\Local\Temp\ipykernel_11356\3474616323.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_df['Name'] = reduced_df['Name'].apply(format_keywords)
# C:\Users\arsla\AppData\Local\Temp\ipykernel_11356\3474616323.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_df['RecipeCategory'] = reduced_df['RecipeCategory'].apply(format_keywords)
# C:\Users\arsla\AppData\Local\Temp\ipykernel_11356\3474616323.py:3: SettingWithCopyWarning:
# ...

# %%
reduced_df.head()
# Out:
#    RecipeId                             Name  \
# 0        38  [Low-FatBerryBlueFrozenDessert]
# 1        39                        [Biryani]
# 2        40                   [BestLemonade]
# 3        41   [Carina'STofu-VegetableKebabs]
# 4        42                    [CabbageSoup]
#
#                                               Images    RecipeCategory  \
# 0  [https://img.sndimg.com/food/image/upload/w_55...  [FrozenDesserts]
# 1  [https://img.sndimg.com/food/image/upload/w_55...   [ChickenBreast]
# 2  [https://img.sndimg.com/food/image/upload/w_55...       [Beverages]
# 3  [https://img.sndimg.com/food/image/upload/w_55...        [Soy/Tofu]
# 4  [https://img.sndimg.com/food/image/upload/w_55...       [Vegetable]
#
#                                             Keywords  \
# 0  [Dessert, LowProtein, LowCholesterol, Healthy,...
# 1  [ChickenThigh&Leg, Chicken, Poultry, Meat, Asi...
# 2  [LowProtein, LowCholesterol, Healthy, Summer, ...
# ...

# %%
reduced_df['Tags'] = reduced_df['Name'] + reduced_df['RecipeCategory'] + reduced_df['RecipeIngredientParts'] + reduced_df['Keywords']
# Out:
# C:\Users\arsla\AppData\Local\Temp\ipykernel_11356\2270022607.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_df['Tags'] = reduced_df['Name'] + reduced_df['RecipeCategory'] + reduced_df['RecipeIngredientParts'] + reduced_df['Keywords']

# %%
reduced_df.head()
# Out:
#    RecipeId                             Name  \
# 0        38  [Low-FatBerryBlueFrozenDessert]
# 1        39                        [Biryani]
# 2        40                   [BestLemonade]
# 3        41   [Carina'STofu-VegetableKebabs]
# 4        42                    [CabbageSoup]
#
#                                               Images    RecipeCategory  \
# 0  [https://img.sndimg.com/food/image/upload/w_55...  [FrozenDesserts]
# 1  [https://img.sndimg.com/food/image/upload/w_55...   [ChickenBreast]
# 2  [https://img.sndimg.com/food/image/upload/w_55...       [Beverages]
# 3  [https://img.sndimg.com/food/image/upload/w_55...        [Soy/Tofu]
# 4  [https://img.sndimg.com/food/image/upload/w_55...       [Vegetable]
#
#                                             Keywords  \
# 0  [Dessert, LowProtein, LowCholesterol, Healthy,...
# 1  [ChickenThigh&Leg, Chicken, Poultry, Meat, Asi...
# 2  [LowProtein, LowCholesterol, Healthy, Summer, ...
# ...

# %%
reduced_df['Tags'][0]
# Out:
# ['Low-FatBerryBlueFrozenDessert',
#  'FrozenDesserts',
#  'Blueberries',
#  'GranulatedSugar',
#  'VanillaYogurt',
#  'LemonJuice',
#  'Dessert',
#  'LowProtein',
#  'LowCholesterol',
#  'Healthy',
#  'FreeOf...',
#  'Summer',
#  'Weeknight',
#  'Freezer',
#  'Easy']

# %%
final_df = reduced_df[['RecipeId', 'Name', 'Calories', 'FatContent', 'CholesterolContent', 'CarbohydrateContent', 'FiberContent', 'ProteinContent', 'Tags']]

# %%
final_df.head()
# Out:
#    RecipeId                             Name  Calories  FatContent  \
# 0        38  [Low-FatBerryBlueFrozenDessert]     170.9         2.5
# 1        39                        [Biryani]    1110.7        58.8
# 2        40                   [BestLemonade]     311.1         0.2
# 3        41   [Carina'STofu-VegetableKebabs]     536.1        24.0
# 4        42                    [CabbageSoup]     103.6         0.4
#
#    CholesterolContent  CarbohydrateContent  FiberContent  ProteinContent  \
# 0                 8.0                 37.1           3.6             3.2
# 1               372.8                 84.4           9.0            63.4
# 2                 0.0                 81.5           0.4             0.3
# 3                 0.0                 64.2          17.3            29.3
# 4                 0.0                 25.1           4.8             4.3
#
#                                                 Tags
# 0  [Low-FatBerryBlueFrozenDessert, FrozenDesserts...
# ...

# %%
final_df['Name'] = recipes_df['Name']
# Out:
# C:\Users\arsla\AppData\Local\Temp\ipykernel_11356\76373278.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['Name'] = recipes_df['Name']

# %%
final_df.head()
# Out:
#    RecipeId                               Name  Calories  FatContent  \
# 0        38  Low-Fat Berry Blue Frozen Dessert     170.9         2.5
# 1        39                            Biryani    1110.7        58.8
# 2        40                      Best Lemonade     311.1         0.2
# 3        41     Carina's Tofu-Vegetable Kebabs     536.1        24.0
# 4        42                       Cabbage Soup     103.6         0.4
#
#    CholesterolContent  CarbohydrateContent  FiberContent  ProteinContent  \
# 0                 8.0                 37.1           3.6             3.2
# 1               372.8                 84.4           9.0            63.4
# 2                 0.0                 81.5           0.4             0.3
# 3                 0.0                 64.2          17.3            29.3
# 4                 0.0                 25.1           4.8             4.3
#
#                                                 Tags
# 0  [Low-FatBerryBlueFrozenDessert, FrozenDesserts...
# ...

# %%
final_df['Tags'] = final_df['Tags'].apply(lambda x: " ".join(x))
# Out:
# C:\Users\arsla\AppData\Local\Temp\ipykernel_11356\541133342.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['Tags'] = final_df['Tags'].apply(lambda x: " ".join(x))

# %%
final_df['Tags'][0]
# Out:
# 'Low-FatBerryBlueFrozenDessert FrozenDesserts Blueberries GranulatedSugar VanillaYogurt LemonJuice Dessert LowProtein LowCholesterol Healthy FreeOf... Summer Weeknight Freezer Easy'

# %%
final_df['Tags'] = final_df['Tags'].apply(lambda x: x.lower())
# Out:
# C:\Users\arsla\AppData\Local\Temp\ipykernel_11356\2216111552.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['Tags'] = final_df['Tags'].apply(lambda x: x.lower())

# %%
final_df.head()
# Out:
#    RecipeId                               Name  Calories  FatContent  \
# 0        38  Low-Fat Berry Blue Frozen Dessert     170.9         2.5
# 1        39                            Biryani    1110.7        58.8
# 2        40                      Best Lemonade     311.1         0.2
# 3        41     Carina's Tofu-Vegetable Kebabs     536.1        24.0
# 4        42                       Cabbage Soup     103.6         0.4
#
#    CholesterolContent  CarbohydrateContent  FiberContent  ProteinContent  \
# 0                 8.0                 37.1           3.6             3.2
# 1               372.8                 84.4           9.0            63.4
# 2                 0.0                 81.5           0.4             0.3
# 3                 0.0                 64.2          17.3            29.3
# 4                 0.0                 25.1           4.8             4.3
#
#                                                 Tags
# 0  low-fatberrybluefrozendessert frozendesserts b...
# ...

# %%
final_df.isnull().sum()
# Out:
# RecipeId               0
# Name                   0
# Calories               0
# FatContent             0
# CholesterolContent     0
# CarbohydrateContent    0
# FiberContent           0
# ProteinContent         0
# Tags                   0
# dtype: int64

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 161513 entries, 0 to 522515
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   RecipeId             161513 non-null  int64
#  1   Name                 161513 non-null  object
#  2   Calories             161513 non-null  float64
#  3   FatContent           161513 non-null  float64
#  4   CholesterolContent   161513 non-null  float64
#  5   CarbohydrateContent  161513 non-null  float64
#  6   FiberContent         161513 non-null  float64
#  7   ProteinContent       161513 non-null  float64
#  8   Tags                 161513 non-null  object
# dtypes: float64(6), int64(1), object(2)
# memory usage: 16.4+ MB

# %%
# final_df.to_csv("../data/archive/final_df.csv", index=False)

# %%
# test_df = pd.read_csv("../data/archive/final_df.csv")

# %%
# test_df.head()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Example using KDE plot (requires Seaborn)
sns.kdeplot(reduced_df['Calories'], fill=True, color='red')
plt.xlabel('Calories')
plt.ylabel('Frequency')
plt.title('Distribution of Calories')
plt.grid(True)
plt.show()

# %%
sns.kdeplot(reduced_df['CarbohydrateContent'], fill=True, color='red')
plt.xlabel('CarbohydrateContent')
plt.ylabel('Frequency')
plt.title('Distribution of CarbohydrateContent')
plt.grid(True)
plt.show()

# %%
sns.kdeplot(reduced_df['CholesterolContent'], fill=True, color='red')
plt.xlabel('Feature Value')
plt.ylabel('Frequency')
plt.title('Distribution of Feature')
plt.grid(True)
plt.show()

# %%
sns.kdeplot(reduced_df['FatContent'], fill=True, color='red')
plt.xlabel('FatContent')
plt.ylabel('Frequency')
plt.title('Distribution of FatContent')
plt.grid(True)
plt.show()

# %%
sns.kdeplot(reduced_df['FiberContent'], fill=True, color='red')
plt.xlabel('FiberContent')
plt.ylabel('Frequency')
plt.title('Distribution of FiberContent')
plt.grid(True)
plt.show()

# %%
sns.kdeplot(reduced_df['ProteinContent'], fill=True, color='red')
plt.xlabel('ProteinContent')
plt.ylabel('Frequency')
plt.title('Distribution of ProteinContent')
plt.grid(True)
plt.show()

# %%
final_df.head()
# Out:
#    RecipeId                               Name  Calories  FatContent  \
# 0        38  Low-Fat Berry Blue Frozen Dessert     170.9         2.5
# 1        39                            Biryani    1110.7        58.8
# 2        40                      Best Lemonade     311.1         0.2
# 3        41     Carina's Tofu-Vegetable Kebabs     536.1        24.0
# 4        42                       Cabbage Soup     103.6         0.4
#
#    CholesterolContent  CarbohydrateContent  FiberContent  ProteinContent  \
# 0                 8.0                 37.1           3.6             3.2
# 1               372.8                 84.4           9.0            63.4
# 2                 0.0                 81.5           0.4             0.3
# 3                 0.0                 64.2          17.3            29.3
# 4                 0.0                 25.1           4.8             4.3
#
#                                                 Tags
# 0  low-fatberrybluefrozendessert frozendesserts b...
# ...

# %%
final_df.describe()
# Out:
#             RecipeId       Calories     FatContent  CholesterolContent  \
# count  161513.000000  161513.000000  161513.000000       161513.000000
# mean   265238.339675     449.374867      22.409129           80.705825
# std    155155.655278     705.876992      43.679381          153.776606
# min        38.000000       0.000000       0.000000            0.000000
# 25%    132625.000000     164.800000       5.200000            2.500000
# 50%    256115.000000     299.300000      12.800000           38.600000
# 75%    394598.000000     501.900000      25.600000          102.800000
# max    541382.000000   44239.800000    4701.100000        11823.800000
#
#        CarbohydrateContent   FiberContent  ProteinContent
# count        161513.000000  161513.000000   161513.000000
# mean             46.018863       3.632200       16.509547
# std              90.119172       6.302291       27.846980
# min               0.000000       0.000000        0.000000
# ...

# %%
def remove_outliers(df, column_name):        
    Q1 = np.percentile(df[column_name], 25)
    Q3 = np.percentile(df[column_name], 75)
    
    IQR = Q3 - Q1

    lower_bound = Q1 - (1.5 * IQR)
    upper_bound = Q3 + (1.5 * IQR)

    outliers = df[(df[column_name] < lower_bound) | (df[column_name] > upper_bound)]

    print(f"Found *{len(outliers)}* outliers in '{column_name}'")

    filtered_df = df[(df[column_name] >= lower_bound) & (df[column_name] <= upper_bound)]

    return filtered_df

# %%
final_df = remove_outliers(final_df, 'Calories')
# Out:
# Found *10767* outliers in 'Calories'

# %%
final_df = remove_outliers(final_df, 'FatContent')
# Out:
# Found *5787* outliers in 'FatContent'

# %%
final_df = remove_outliers(final_df, 'CholesterolContent')
# Out:
# Found *6259* outliers in 'CholesterolContent'

# %%
final_df = remove_outliers(final_df, 'CarbohydrateContent')
# Out:
# Found *5276* outliers in 'CarbohydrateContent'

# %%
final_df = remove_outliers(final_df, 'FiberContent')
# Out:
# Found *7616* outliers in 'FiberContent'

# %%
final_df = remove_outliers(final_df, 'ProteinContent')
# Out:
# Found *6424* outliers in 'ProteinContent'

# %%
final_df.head()
# Out:
#    RecipeId                                        Name  Calories  FatContent  \
# 0        38           Low-Fat Berry Blue Frozen Dessert     170.9         2.5
# 2        40                               Best Lemonade     311.1         0.2
# 4        42                                Cabbage Soup     103.6         0.4
# 7        45  Buttermilk Pie With Gingersnap Crumb Crust     228.0         7.1
# 9        47                        Butter Pecan Cookies      69.0         5.6
#
#    CholesterolContent  CarbohydrateContent  FiberContent  ProteinContent  \
# 0                 8.0                 37.1           3.6             3.2
# 2                 0.0                 81.5           0.4             0.3
# 4                 0.0                 25.1           4.8             4.3
# 7                24.5                 37.5           0.5             4.2
# 9                 6.3                  4.5           0.6             0.8
#
#                                                 Tags
# ...

# %%
final_df.shape
# Out:
# (119384, 9)

# %%
df_copy = final_df.copy()

# %%
df_copy.head()
# Out:
#    RecipeId                                        Name  Calories  FatContent  \
# 0        38           Low-Fat Berry Blue Frozen Dessert     170.9         2.5
# 2        40                               Best Lemonade     311.1         0.2
# 4        42                                Cabbage Soup     103.6         0.4
# 7        45  Buttermilk Pie With Gingersnap Crumb Crust     228.0         7.1
# 9        47                        Butter Pecan Cookies      69.0         5.6
#
#    CholesterolContent  CarbohydrateContent  FiberContent  ProteinContent  \
# 0                 8.0                 37.1           3.6             3.2
# 2                 0.0                 81.5           0.4             0.3
# 4                 0.0                 25.1           4.8             4.3
# 7                24.5                 37.5           0.5             4.2
# 9                 6.3                  4.5           0.6             0.8
#
#                                                 Tags
# ...

# %%
from sklearn.preprocessing import PowerTransformer

pt = PowerTransformer(method='yeo-johnson')

df_copy[['Calories', 'FatContent', 'CholesterolContent', 'CarbohydrateContent', 'FiberContent', 'ProteinContent']] = pt.fit_transform(df_copy[
    ['Calories', 'FatContent', 'CholesterolContent', 'CarbohydrateContent', 'FiberContent', 'ProteinContent']
    ])

# %%
sns.kdeplot(df_copy[['Calories', 'FatContent', 'CholesterolContent', 'CarbohydrateContent', 'FiberContent', 'ProteinContent']], legend=True, cbar=True)
plt.xlabel('Features')
plt.ylabel('Frequency')
plt.title('Yeo-Johnson Transformation')
plt.grid(True)
plt.show()

# %%
df_copy.describe()
# Out:
#             RecipeId      Calories    FatContent  CholesterolContent  \
# count  119384.000000  1.193840e+05  1.193840e+05        1.193840e+05
# mean   265392.223665 -4.584031e-16 -1.704579e-16       -3.258579e-16
# std    153701.139931  1.000004e+00  1.000004e+00        1.000004e+00
# min        38.000000 -2.603541e+00 -1.810602e+00       -1.387502e+00
# 25%    134792.000000 -6.983534e-01 -7.044477e-01       -1.271793e+00
# 50%    257518.000000  3.562191e-04  4.094527e-02        1.735645e-01
# 75%    392430.750000  7.170638e-01  7.439320e-01        8.612156e-01
# max    541382.000000  3.196688e+00  2.203867e+00        1.815215e+00
#
#        CarbohydrateContent  FiberContent  ProteinContent
# count         1.193840e+05  1.193840e+05    1.193840e+05
# mean          1.923603e-16 -1.712911e-16   -3.209179e-16
# std           1.000004e+00  1.000004e+00    1.000004e+00
# min          -2.175114e+00 -1.690044e+00   -1.962625e+00
# 25%          -7.234779e-01 -7.600720e-01   -7.230211e-01
# ...

# %%
df_copy.head()
# Out:
#    RecipeId                                        Name  Calories  FatContent  \
# 0        38           Low-Fat Berry Blue Frozen Dessert -0.403134   -0.998503
# 2        40                               Best Lemonade  0.468896   -1.710852
# 4        42                                Cabbage Soup -0.946701   -1.622066
# 7        45  Buttermilk Pie With Gingersnap Crumb Crust -0.017918   -0.252097
# 9        47                        Butter Pecan Cookies -1.293043   -0.452301
#
#    CholesterolContent  CarbohydrateContent  FiberContent  ProteinContent  \
# 0           -0.469210             0.663689      0.893565       -0.506973
# 2           -1.387502             1.975630     -1.096327       -1.698527
# 4           -1.387502             0.151345      1.262301       -0.268446
# 7            0.129784             0.678929     -0.976313       -0.288005
# 9           -0.575204            -1.318218     -0.864574       -1.369699
#
#                                                 Tags
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

df_copy[['Calories', 'FatContent', 'CholesterolContent', 'CarbohydrateContent', 'FiberContent', 'ProteinContent']] = scaler.fit_transform(df_copy[['Calories', 'FatContent', 'CholesterolContent', 'CarbohydrateContent', 'FiberContent', 'ProteinContent']])

# %%
sns.kdeplot(df_copy[['Calories', 'FatContent', 'CholesterolContent', 'CarbohydrateContent', 'FiberContent', 'ProteinContent']], legend=True, cbar=True)
plt.xlabel('Features')
plt.ylabel('Frequency')
plt.title('MinMaxScaler')
plt.grid(True)
plt.show()

# %%
df_copy.describe()
# Out:
#             RecipeId       Calories     FatContent  CholesterolContent  \
# count  119384.000000  119384.000000  119384.000000       119384.000000
# mean   265392.223665       0.448869       0.451019            0.433227
# std    153701.139931       0.172408       0.249100            0.312236
# min        38.000000       0.000000       0.000000            0.000000
# 25%    134792.000000       0.328468       0.275542            0.036128
# 50%    257518.000000       0.448930       0.461218            0.487419
# 75%    392430.750000       0.572495       0.636332            0.702128
# max    541382.000000       1.000000       1.000000            1.000000
#
#        CarbohydrateContent   FiberContent  ProteinContent
# count        119384.000000  119384.000000   119384.000000
# mean              0.493041       0.456596        0.519389
# std               0.226675       0.270169        0.264641
# min               0.000000       0.000000        0.000000
# ...

# %%
df_copy.head()
# Out:
#    RecipeId                                        Name  Calories  FatContent  \
# 0        38           Low-Fat Berry Blue Frozen Dessert  0.379366    0.202293
# 2        40                               Best Lemonade  0.529710    0.024848
# 4        42                                Cabbage Soup  0.285651    0.046964
# 7        45  Buttermilk Pie With Gingersnap Crumb Crust  0.445779    0.388222
# 9        47                        Butter Pecan Cookies  0.225939    0.338351
#
#    CholesterolContent  CarbohydrateContent  FiberContent  ProteinContent  \
# 0            0.286723             0.643482      0.698009        0.385224
# 2            0.000000             0.940865      0.160404        0.069891
# 4            0.000000             0.527347      0.797630        0.448347
# 7            0.473750             0.646937      0.192827        0.443171
# 9            0.253628             0.194236      0.223016        0.156912
#
#                                                 Tags
# ...

# %%
df_copy['Tags'][0]
# Out:
# 'low-fatberrybluefrozendessert frozendesserts blueberries granulatedsugar vanillayogurt lemonjuice dessert lowprotein lowcholesterol healthy freeof... summer weeknight freezer easy'

# %%
df_copy.to_csv("../data/processesd_df.csv", index=False)

# %%
final_df.head()
# Out:
#    RecipeId                                        Name  Calories  FatContent  \
# 0        38           Low-Fat Berry Blue Frozen Dessert     170.9         2.5
# 2        40                               Best Lemonade     311.1         0.2
# 4        42                                Cabbage Soup     103.6         0.4
# 7        45  Buttermilk Pie With Gingersnap Crumb Crust     228.0         7.1
# 9        47                        Butter Pecan Cookies      69.0         5.6
#
#    CholesterolContent  CarbohydrateContent  FiberContent  ProteinContent  \
# 0                 8.0                 37.1           3.6             3.2
# 2                 0.0                 81.5           0.4             0.3
# 4                 0.0                 25.1           4.8             4.3
# 7                24.5                 37.5           0.5             4.2
# 9                 6.3                  4.5           0.6             0.8
#
#                                                 Tags
# ...

# %%
df_copy.head()
# Out:
#    RecipeId                                        Name  Calories  FatContent  \
# 0        38           Low-Fat Berry Blue Frozen Dessert  0.379366    0.202293
# 2        40                               Best Lemonade  0.529710    0.024848
# 4        42                                Cabbage Soup  0.285651    0.046964
# 7        45  Buttermilk Pie With Gingersnap Crumb Crust  0.445779    0.388222
# 9        47                        Butter Pecan Cookies  0.225939    0.338351
#
#    CholesterolContent  CarbohydrateContent  FiberContent  ProteinContent  \
# 0            0.286723             0.643482      0.698009        0.385224
# 2            0.000000             0.940865      0.160404        0.069891
# 4            0.000000             0.527347      0.797630        0.448347
# 7            0.473750             0.646937      0.192827        0.443171
# 9            0.253628             0.194236      0.223016        0.156912
#
#                                                 Tags
# ...

# %%
max_words_in_tags = df_copy['Tags'].apply(lambda x: len(x.split())).max()

# %%
max_words_in_tags
# Out:
# np.int64(52)

# %%
print(df_copy.info(memory_usage="deep"))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 119384 entries, 0 to 522515
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   RecipeId             119384 non-null  int64
#  1   Name                 119384 non-null  object
#  2   Calories             119384 non-null  float64
#  3   FatContent           119384 non-null  float64
#  4   CholesterolContent   119384 non-null  float64
#  5   CarbohydrateContent  119384 non-null  float64
#  6   FiberContent         119384 non-null  float64
#  7   ProteinContent       119384 non-null  float64
#  8   Tags                 119384 non-null  object
# dtypes: float64(6), int64(1), object(2)
# memory usage: 44.0 MB
# None

# %%
from sklearn.feature_extraction.text import CountVectorizer
count_vec = CountVectorizer(max_features=5000, stop_words='english', min_df=5, max_df=0.8)

# %%
tags_vectors = count_vec.fit_transform(df_copy['Tags'])

# %%
tags_vectors.shape
# Out:
# (119384, 5000)

# %%
len(count_vec.get_feature_names_out())
# Out:
# 5000

# %%
count_vec.get_feature_names_out().tolist()
# Out:
# ['10',
#  '100',
#  '12',
#  '15',
#  '15mins',
#  '1940',
#  '1point',
#  '1pt',
#  '1wwpoint',
#  '20',
#  '21daywonderdiet',
#  '2bleu',
#  '2ingredients',
#  '2lb',
#  '2pts',
#  '2wwpoints',
#  '30',
#  '30mins',
#  '3ingredients',
#  '3points',
#  '3wwpoints',
#  '4hours',
#  '4ingredients',
#  '4points',
#  '4wwpoints',
#  '5fix',
#  '5ingredients',
#  '5points',
#  '5wwpoints',
#  '60mins',
#  'a1',
#  'aacute',
#  'aarsi',
#  'abby',
#  'abm',
#  'absinthe',
#  'absolutcitronvodka',
#  'absolutkurantvodka',
#  'absolutmandarinvodka',
#  'absolutvodka',
#  'acadia',
#  'accentseasoning',
#  'acinidipepepasta',
#  'acirc',
#  'acolada',
#  'acornsquash',
#  'actingactivedryyeast',
#  'actingbakingpowder',
#  'activedryyeast',
#  'adam',
#  'added',
#  'addedchickenbroth',
#  'addeddicedtomatoes',
#  'addedstewedtomatoes',
#  'addedtomatosauce',
#  'addedwholetomatoes',
#  'adobosauce',
#  'adoboseasoning',
#  'adult',
#  'adultbeverage',
#  'adzukibeans',
#  'african',
# ...

# %%
count_vec.get_feature_names_out().tolist()[-5000:-1:200]
# Out:
# ['10',
#  'asia',
#  'beefflanksteak',
#  'boursincheese',
#  'caramel',
#  'chickenpiccata',
#  'colcannon',
#  'custard',
#  'dryvermouth',
#  'forone',
#  'fromscratch',
#  'granulatedsugar',
#  'healthyversion',
#  'jennifer',
#  'lime',
#  'middleeast',
#  'oatmealpancakes',
#  'pickledcucumbers',
#  'quesofresco',
#  'roastedsweetpeppers',
#  'semi',
#  'soybeans',
#  'sultanas',
#  'tomatojuice',
#  'warmwater']

# %%
from sklearn.nei

# %%
similarity = cosine_similarity(tags_vectors)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[238], line 1
# ----> 1 similarity = cosine_similarity(tags_vectors)
#
# File e:\Food-Recommendation-System\venv\Lib\site-packages\sklearn\utils\_param_validation.py:216, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     210 try:
#     211     with config_context(
#     212         skip_parameter_validation=(
#     213             prefer_skip_nested_validation or global_skip_validation
#     214         )
#     215     ):
# --> 216         return func(*args, **kwargs)
#     217 except InvalidParameterError as e:
#     218     # When the function is just a wrapper around an estimator, we allow
#     219     # the function to delegate validation to the estimator, but we replace
#     220     # the name of the estimator by the name of the function in the error
# ...

# %%
similarity

# %%
df_copy[df_copy['Name'] == 'Best Lemonade']
